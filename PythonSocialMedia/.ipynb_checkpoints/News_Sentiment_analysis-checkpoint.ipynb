# %%
# Dependencies
import tweepy
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import datetime
import seaborn as sns

# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Twitter API Credentials
consumer_key = "CO1KM8I923P511oRqe2agcNRK"
consumer_secret ="NwNxCoR3hw9L56Yi4cYCh7w4ie5qoFfRHjUPlS0OSHYW35TDZ1"
access_token = "907734120847028224-MZ7bjMY7RVlpEoOAFHWRlcbDU9THp2B"
access_token_secret = "E6CfTIvLMDJRE2lzj2ClB0fUIcTZ3hRtof9EpW1uxCqql"

# Use Tweepy to Authenticate our access
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target User for News channel

news_list=["@CNN","@CBS","@BBC","@FoxNews","@nytimes"]

# Variables for holding sentiments
compound_list = []
positive_list = []
negative_list = []
neutral_list = []

#create dataframe 
news_tweet=pd.DataFrame(columns=["News Channel","Text","Dated","Compound","Positive","Negative","Neutral"])
news_tweet
# Out:
# Empty DataFrame
# Columns: [News Channel, Text, Dated, Compound, Positive, Negative, Neutral]
# Index: []

# %%
# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):
    
    for item in news_list:

        # Get all tweets from home feed
        public_tweets = api.user_timeline(item)

        # Loop through all tweets
        for tweet in public_tweets:
            
            try:
            
                tweet_name=tweet["user"]["screen_name"]
                tweet_date=tweet["created_at"]
                tweet_text=tweet["text"]

                # Run Vader Analysis on each tweet
                compound = analyzer.polarity_scores(tweet_text)["compound"]
                pos = analyzer.polarity_scores(tweet_text)["pos"]
                neu = analyzer.polarity_scores(tweet_text)["neu"]
                neg = analyzer.polarity_scores(tweet_text)["neg"]

                #Entering the values in dataframe
                news_tweet = news_tweet.append([{"News Channel":tweet_name,
                                                 "Text":tweet_text,
                                                 "Dated":tweet_date,
                                                 "Compound":compound,
                                                 "Positive":pos,
                                                 "Negative":neu,
                                                 "Neutral":neg
                                                }],ignore_index=True)
            except:
                
                print("No Values")

# %%
news_tweet
# Out:
#     News Channel                                               Text  \
# 0            CNN  Aung San Suu Kyi "doesn't really have the auth...
# 1            CNN  .@FareedZakaria imagines what an interview wit...
# 2            CNN  .@DanaBashCNN: Are you up for another 6 years ...
# 3            CNN  Sen. Dianne Feinstein: “I have never been in a...
# 4            CNN  Sen. Dianne Feinstein says Donald Trump Jr.’s ...
# 5            CNN  "We all feel for dreamers...but the United Sta...
# 6            CNN  UN Ambassador Nikki Haley on Trump’s use of Tw...
# 7            CNN  A British Airways flight was held at Paris air...
# 8            CNN  “Everybody” sees the sanctions on North Korea ...
# 9            CNN  UN Ambassador Nikki Haley: “It is a new day at...
# 10           CNN  Could North Korea help Iran develop nuclear we...
# 11           CNN  Protests continued in St. Louis last night aft...
# 12           CNN  Yes, climate change made Harvey and Irma worse...
# 13           CNN  California wants to pick the 2020 Democratic p...
# 14           CNN  Fake news about US politics is big business in...
# 15           CNN  How extensive was Russia's use of Facebook to ...
# 16           CNN  Leonardo da Vinci crafted one of the machines ...
# 17           CNN  "We've been thrilled to have them": Millionair...
# 18           CNN  Second man arrested in London in connection wi...
# 19           CNN  Singapore, Nordic countries are above the US i...
# 20           CBS  Get ready for football! Stream NFL on CBS toda...
# 21           CBS  Tonight's the night! Here's everything you nee...
# 22           CBS  RT @colbertlateshow: The most important part o...
# 480  Sun Sep 17 14:30:03 +0000 2017    0.4588     0.200     0.800    0.000
# 481  Sun Sep 17 14:20:10 +0000 2017   -0.6124     0.000     0.737    0.263
# 482  Sun Sep 17 14:10:03 +0000 2017    0.0000     0.000     1.000    0.000
# 483  Sun Sep 17 13:58:43 +0000 2017   -0.4588     0.000     0.727    0.273
# 484  Sun Sep 17 13:55:01 +0000 2017    0.0000     0.000     1.000    0.000
# 485  Sun Sep 17 13:40:06 +0000 2017    0.2023     0.184     0.816    0.000
# 486  Sun Sep 17 13:25:04 +0000 2017   -0.3182     0.000     0.867    0.133
# 487  Sun Sep 17 13:10:05 +0000 2017   -0.6597     0.000     0.794    0.206
# 488  Sun Sep 17 12:55:02 +0000 2017   -0.3818     0.000     0.867    0.133
# 489  Sun Sep 17 12:40:03 +0000 2017   -0.5423     0.000     0.774    0.226
# 490  Sun Sep 17 12:24:05 +0000 2017    0.0000     0.000     1.000    0.000
# 491  Sun Sep 17 12:23:48 +0000 2017    0.0000     0.000     1.000    0.000
# 492  Sun Sep 17 12:10:02 +0000 2017    0.4215     0.141     0.859    0.000
# 493  Sun Sep 17 11:55:02 +0000 2017   -0.4939     0.000     0.781    0.219
# 494  Sun Sep 17 11:28:57 +0000 2017   -0.4588     0.000     0.842    0.158
# 495  Sun Sep 17 11:11:04 +0000 2017    0.0000     0.000     1.000    0.000
# 496  Sun Sep 17 10:55:03 +0000 2017    0.0000     0.000     1.000    0.000
# 497  Sun Sep 17 10:48:40 +0000 2017    0.0000     0.000     1.000    0.000
# 498  Sun Sep 17 10:31:38 +0000 2017    0.0000     0.000     1.000    0.000
# 499  Sun Sep 17 10:14:09 +0000 2017    0.4927     0.132     0.868    0.000
#
# [500 rows x 7 columns]

# %%
news_tweet["News Channel"].unique()
# Out:
# array(['CNN', 'CBS', 'BBC', 'FoxNews', 'nytimes'], dtype=object)

# %%
news_tweet.to_csv('newsoutputanalysis.csv', index=False)

# %%
newsfeedanalysis_cnn=news_tweet.loc[news_tweet["News Channel"]=="CNN"]
newsfeedanalysis_cbs=news_tweet.loc[news_tweet["News Channel"]=="CBS"]
newsfeedanalysis_bbc=news_tweet.loc[news_tweet["News Channel"]=="BBC"]
newsfeedanalysis_fox=news_tweet.loc[news_tweet["News Channel"]=="FoxNews"]
newsfeedanalysis_nytime=news_tweet.loc[news_tweet["News Channel"]=="nytimes"]

# %%
x_cnn=np.arange(len(newsfeedanalysis_cnn))
x_cbs=np.arange(len(newsfeedanalysis_cbs))
x_bbc=np.arange(len(newsfeedanalysis_bbc))
x_fox=np.arange(len(newsfeedanalysis_fox))
x_ny=np.arange(len(newsfeedanalysis_nytime))

cnn=plt.scatter(x_cnn,newsfeedanalysis_cnn["Compound"],marker="o",facecolors="Red",edgecolors="black",s=100, alpha=1,label="CNN")
cbs=plt.scatter(x_cbs,newsfeedanalysis_cbs["Compound"],marker="o",facecolors="DarkBlue",edgecolors="black",s=100, alpha=1,label="CBS")
bbc=plt.scatter(x_bbc,newsfeedanalysis_bbc["Compound"],marker="o",facecolors="Yellow",edgecolors="black",s=100, alpha=1,label="BBC")
fox=plt.scatter(x_fox,newsfeedanalysis_fox["Compound"],marker="o",facecolors="Green",edgecolors="black",s=100, alpha=1,label="FOX")
ny=plt.scatter(x_ny,newsfeedanalysis_nytime["Compound"],marker="o",facecolors="Aqua",edgecolors="black",s=100, alpha=1,label="NYTimes")

plt.xlim([0,100])
# Out:
# (0, 100)

# %%
#time stamp for title

t=datetime.date.today()

# %%
#adding the text to axis and overall title
plt.title('Sentiment Analysis of Tweet as of ' + str(t), fontsize=15)
plt.xlabel('Tweet Ago', fontsize=9)
plt.ylabel('Tweet Polarity', fontsize=9)

#grid on
plt.grid()
#plot the legend out side
plt.legend(handles=[cnn,cbs,bbc,fox,ny], loc='center left', bbox_to_anchor=(1, 0.5))

#increase the plot size
plt.rcParams["figure.figsize"] = (10,8)

ax = plt.gca()
ax.set_facecolor('cornflowerblue')
ax.patch.set_alpha(0.1)

#save the figure

plt.savefig('Sentiment_Analysis.png')
#show the plot
plt.show()

# %%
#overall sentiment for each new channel

analysis_means=round(news_tweet.groupby(news_tweet["News Channel"]).mean(),2)
analysis_means
# Out:
#               Compound  Positive  Negative  Neutral
# News Channel
# BBC               0.09      0.08      0.87     0.05
# CBS               0.57      0.24      0.76     0.00
# CNN              -0.02      0.05      0.88     0.07
# FoxNews           0.01      0.08      0.85     0.07
# nytimes          -0.12      0.03      0.89     0.08

# %%
#Get the values for x-axis and Y-axis

label=[]
y_axis=[]

for index,row in analysis_means.iterrows():
    
    l=index
    y=row["Compound"]
    label.append(l)
    y_axis.append(y)

# %%
x_axis=np.arange(len(lable))
# Out:
# News Channel
# BBC        0.09
# CBS        0.57
# CNN       -0.02
# FoxNews    0.01
# nytimes   -0.12
# Name: Compound, dtype: float64

# %%
# plot the bar graph with Seaborn library


# Sets the x limits of the current chart

plt.xlim(0, len(x_axis))

#color palatte based on value of y

lenth=len(y_axis)

color=["green" if (y_axis[i]>0) else "red" for i in range(lenth)]

#plot the Bar graph

ax = sns.barplot(x_axis,y_axis,palette=color)
barwidth = [0.4,0.4,0.4,0.4,0.4]
ax.set_ylim(0, 0.7)
label_ = analysis_means.Compound

for bar,newwidth, label in zip(ax.patches,barwidth, label_):
    x = bar.get_x()
    width = bar.get_width()
    height = bar.get_height()

    centre = x+width/2.
    bar.set_x(centre-newwidth/2.)
    bar.set_width(newwidth)

    ax.text(x+width/2.,
            height + 0.03,
            '{0:4.2f}'.format(label),
            ha="center")

# %%
# Tell matplotlib where we would like to place each of our x axis headers

#tick_locations = [value-0.4 for value in x_axis]
#plt.xticks(tick_locations,label)

# %%
# Give our chart some labels and a tile
plt.title('Overall Sentiment Analysis of Tweet as of ' + str(t), fontsize=15)
#plt.ylabel("Twitter Polarity")

# %%
plt.show()
